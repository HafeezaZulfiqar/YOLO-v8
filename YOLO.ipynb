# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# Build a YOLOv9c model from pretrained weight
model = YOLO('yolov9c.pt')

# Run inference 
#results = model('a.jpg', save=True)
results = model('D:/JupyterNotebook/testvideo.mp4', save=True)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 49.4M/49.4M [01:12<00:00, 717kB/s]
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1845) D:\JupyterNotebook\testvideo.mp4: 384x640 12 persons, 4 bicycles, 8 cars, 5 traffic lights, 1 fire hydrant, 1857.6ms
# video 1/1 (frame 2/1845) D:\JupyterNotebook\testvideo.mp4: 384x640 11 persons, 3 bicycles, 8 cars, 5 traffic lights, 1 fire hydrant, 1 backpack, 1507.8ms
# ...

# %%
from ultralytics import YOLO

# Load an official or custom model
model = YOLO('yolov9c.pt') 

# Perform tracking with the model
 # Tracking with default tracker
#results = model.track(source="1.mp4", show=True)  # Tracking with ByteTrack tracker
#results = model.track(source="test_videos/1.mp4", save=True)
results = model.track(source='D:/JupyterNotebook/testvideo.mp4', save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1845) D:\JupyterNotebook\testvideo.mp4: 384x640 7 persons, 3 bicycles, 4 cars, 2 traffic lights, 1 fire hydrant, 1780.7ms
# video 1/1 (frame 2/1845) D:\JupyterNotebook\testvideo.mp4: 384x640 7 persons, 3 bicycles, 4 cars, 2 traffic lights, 1 fire hydrant, 1411.0ms
# video 1/1 (frame 3/1845) D:\JupyterNotebook\testvideo.mp4: 384x640 7 persons, 3 bicycles, 4 cars, 2 traffic lights, 1 fire hydrant, 1401.1ms
# ...

# %%
from ultralytics import YOLO


#https://universe.roboflow.com/mahmoud-9wyf6/fire-n-smoke-detection/dataset/1/download/yolov8

# Build a YOLOv9c model from pretrained weight
model = YOLO('yolov9c.pt')

# Train the model for 100 epochs
results = model.train(data='data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.4  Python-3.12.2 torch-2.3.0+cu121 CPU (Intel Core(TM) i5-4200M 2.50GHz)
# ...
